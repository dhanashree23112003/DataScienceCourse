# %%
'''
File Handling/File I/O

Volatile & Non- volatile memory

storage - Ram & HDD(Hard disk drive), SSD(Solid State Drive)
storing in ssd and hhd makes sure that the memory is there

but in Ram it's not like that

Binary File, Txt file, pptx, .exe, .py, JPG

File operations:

Read,write, modify, delete, save, create a file

'''

# %% [markdown]
# # File Handling

# %%
'''
r - Reading the File
w - Writing in a file
a - Appending in a file, if there is no file it will create a file
b - Binary file
t - text
x - Creating a file, if the file exists i will throw an error else a file will be created
+ -> read and write in the file at the same time
'''

# %%
file = "Hey, today is not yesterday"

# %%
file.a("Hey, today is not yesterday")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-d4b3a2134bfb> in <cell line: 1>()
# ----> 1 file.a("Hey, today is not yesterday")
#
# AttributeError: 'str' object has no attribute 'a'

# %%
f = open('/content/sample-1.txt') # by default this is set tor ead mode which is r
f.read(10)
# Out:
# '\ufeffSample Do'

# %%
f.read(10) #it prints out next 10 charecter
# Out:
# 'cument\n\nFu'

# %%
print(f.read())
# Out:
# sce convallis metus id felis luctus adipiscing. Pellentesque egestas, neque sit amet convallis pulvinar, justo nulla eleifend augue, ac auctor orci leo non est. Fusce vel dui. Sed augue ipsum, egestas nec, vestibulum et, malesuada adipiscing, dui. Phasellus viverra nulla ut metus varius laoreet.
#
#
# Nulla facilisi. Phasellus accumsan cursus velit. Curabitur at lacus ac velit ornare lobortis. Maecenas vestibulum mollis diam. Phasellus blandit leo ut odio.
#
#
# Praesent ac massa at ligula laoreet iaculis. Pellentesque dapibus hendrerit tortor. Nam commodo suscipit quam. Sed a libero. Nullam nulla eros, ultricies sit amet, nonummy id, imperdiet feugiat, pede.
#
#
# Pellentesque egestas, neque sit amet convallis pulvinar, justo nulla eleifend augue, ac auctor orci leo non est. Curabitur ullamcorper ultricies nisi. Pellentesque posuere. Fusce fermentum. Morbi vestibulum volutpat enim.
#
#
# ...

# %%
f.read()
f.readline()
# Out:
# ''

# %%
f.read()
# Out:
# ''

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# '\ufeffSample Document\n'

# %%
f.readlines() # it prints out list, which starts from where the f.read() ends
# Out:
# ['\n',
#  'Fusce convallis metus id felis luctus adipiscing. Pellentesque egestas, neque sit amet convallis pulvinar, justo nulla eleifend augue, ac auctor orci leo non est. Fusce vel dui. Sed augue ipsum, egestas nec, vestibulum et, malesuada adipiscing, dui. Phasellus viverra nulla ut metus varius laoreet.\n',
#  '\n',
#  '\n',
#  'Nulla facilisi. Phasellus accumsan cursus velit. Curabitur at lacus ac velit ornare lobortis. Maecenas vestibulum mollis diam. Phasellus blandit leo ut odio.\n',
#  '\n',
#  '\n',
#  'Praesent ac massa at ligula laoreet iaculis. Pellentesque dapibus hendrerit tortor. Nam commodo suscipit quam. Sed a libero. Nullam nulla eros, ultricies sit amet, nonummy id, imperdiet feugiat, pede.\n',
#  '\n',
#  '\n',
#  'Pellentesque egestas, neque sit amet convallis pulvinar, justo nulla eleifend augue, ac auctor orci leo non est. Curabitur ullamcorper ultricies nisi. Pellentesque posuere. Fusce fermentum. Morbi vestibulum volutpat enim.\n',
#  '\n',
#  '\n',
# ...

# %%
f.seek(0)
arr = f.readlines()

# %%
len(arr) # it will not give any value because curosr will be at the end of the line
# Out:
# 15

# %%
for i in arr:
  print(f"{i} + Yes")
# Out:
# ﻿Sample Document
#  + Yes
#
#  + Yes
# Fusce convallis metus id felis luctus adipiscing. Pellentesque egestas, neque sit amet convallis pulvinar, justo nulla eleifend augue, ac auctor orci leo non est. Fusce vel dui. Sed augue ipsum, egestas nec, vestibulum et, malesuada adipiscing, dui. Phasellus viverra nulla ut metus varius laoreet.
#  + Yes
#
#  + Yes
#
#  + Yes
# Nulla facilisi. Phasellus accumsan cursus velit. Curabitur at lacus ac velit ornare lobortis. Maecenas vestibulum mollis diam. Phasellus blandit leo ut odio.
#  + Yes
#
#  + Yes
#
#  + Yes
# Praesent ac massa at ligula laoreet iaculis. Pellentesque dapibus hendrerit tortor. Nam commodo suscipit quam. Sed a libero. Nullam nulla eros, ultricies sit amet, nonummy id, imperdiet feugiat, pede.
#  + Yes
#
#  + Yes
#
#  + Yes
# ...

# %%
f.read()
# Out:
# ''

# %% [markdown]
# # Write

# %%
f = open('/content/sample-1.txt', "w") # since the mode is alreay in read, we have say"w"" to write

# %%
f.write("\n Black widow (New)")
# Out:
# 19

# %%
f.close()

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-57-571e9fb02258> in <cell line: 1>()
# ----> 1 f.read()
#
# UnsupportedOperation: not readable

# %%
f = open('/content/sample-1.txt')

# %%
f.read()
# Out:
# '\n Black widow (New)'

# %%
'''
rt = read text, which is laready default
wb = write binary
rb = read binary file
xt = create text file
xb = create binary file
'''

# %%
f = open('/content/sample-1.txt',)

# %%
f.write("New language")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-68-aa109bd72c56> in <cell line: 1>()
# ----> 1 f.write("New language")
#
# UnsupportedOperation: not writable

# %%
f = open('/content/sample-1.txt',"w")

# %%
f.readable()
# Out:
# False

# %%
f = open('/content/sample-1.txt', "r+")

# %%
f.read()
# Out:
# ''

# %%
f.write("Avengers")
# Out:
# 8

# %%
f.seek(0)
f.read()
# Out:
# 'Avengers'

# %%
f.write("\n New Form \n")
# Out:
# 12

# %%
f.seek(0)
f.read()
# Out:
# 'Avengers\n New Form \n'

# %%
'''
Avengers will not get erased because it uses + which is append mode
'''
# Out:
# '\nAvengers will not get erased because it uses + which is append mode\n'

# %%
fi = open('/content/sample-124.txt', "x+")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-94-08da78fdbb97> in <cell line: 1>()
# ----> 1 fi = open('/content/sample-124.txt', "x+")
#
# FileExistsError: [Errno 17] File exists: '/content/sample-124.txt'

# %%
f.close()

# %%
file = open(filelocation, "x")

# %%
fi.write("New file")#if we do only"x", then it only aloows us to write but not read
#Do "x+" toread & and write
# Out:
# 8

# %%
fi.seek(0)
# Out:
# 0

# %%
fi.read()
# Out:
# 'New file'

# %%
f.close()

# %%
fi = open('/content/sample-10.txt', "x+")

# %%
'''fi.write("New file")
fi.seek(0)
fi.write("File hehe")
fi.write(" wot ")
fi.seek(0)
fi.read()'''
# Out:
# 'File hehe wot '

# %%
fi.write("New file")
fi.seek(0)
# Out:
# 0

# %%
fi.write(" wot ")
fi.seek(0)
# Out:
# 0

# %%
fi.write("File hehe")
fi.seek(0)
# Out:
# 0

# %%
fi = open('/content/sample-10.txt',"r+")
fi.read()
# Out:
# 'File hehe wot New file'

# %%
fi.seek(0)
# Out:
# 0

# %%
fi.read()
# Out:
# 'File hehe wot New file'

# %%
fi.seek(0)
fi.write("Top")
fi.seek(0)
# Out:
# 0

# %%
fi.read() #Over placing the charecters in the output
# Out:
# 'Tope hehe wot New file'

# %%
fi.write("down") #First it will write down then it will seek to 0
fi.seek(0)
# Out:
# 0

# %%
fi.read()
# Out:
# 'Tope hehe wot New filedown'

# %%
fi.write("down")
fi.seek(0)
# Out:
# 0

# %%
fi.read()
# Out:
# 'Tope hehe wot New filedowndown'

# %%
f.close()

# %%
'''
with =  closes the file after operations

'''

# %%
f = open('/content/sample-10.txt',"r+")

# %%
with open('/content/sample-10.txt',"r+") as f: # it the same as:
#f = open('/content/sample-10.txt',"r+")
  print(f.read())
# Out:
# Tope hehe wot New filedowndown

# %%
#Now we dont nned to add close cuz we are using
#with

# %%
'''
Diffreence b\w module, package, libarary, frameowrk,
:

Module : A module is a file containing Python code. A single file
Package : A package is a collection of Python modules. A collection of pmodule
Library : A library is a collection of related modules. A collection of package
Framework : A framework is a collection of related modules / Library.

'''

import math # It is a library, built with lot of collection of packages

# %%
'''
flask = framework
django = framework
'''

#pip install can be library, package or framework
#pip is python installer

# %%
#For collab: !pip install xyz

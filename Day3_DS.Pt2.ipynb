# %% [markdown]
# Conditional Statements

# %%
a == b
a != b
a < b
a > b
a >= b
a <= b

# %%
if England wins -> I'm getting 5000 extra
if Italy wins -> I'm getting 3000 extra

winner = ""

# %%
winner = input("Who won? ")
if winner == "England":
    print("I'm getting 5000 extra")
else:
    print("I'm getting Chores")
# Out:
# Who won? meow
# I'm getting Chores

# %%
price = int(input("How much money?  "))

if price < 100:
  print("buy snacks")
elif price == 100:
  print("buy books")
elif price > 100:
  print("buy purse")
else:
  print("Cry my heart out")
# Out:
# How much money?  10000
# buy purse

# %%
stri = "Money"

# %%
stri == False
# Out:
# False

# %%
try:
  if stri:
    print("Hello world")
except:
    print("bye world")
# Out:
# Hello world

# %%
listi = [1,2,3,4,5]

# %%
if 1 in listi:
  print("Hello")
elif 6 not in listi:
  listi.append("Meow meow")
else:
  listi.clear()
# Out:
# Hello

# %%
inp = input("Enter name")

if inp.isnumeric():
  print("sorry")
elif inp.isalpha():
  print("you are nice")
else:
  print("you are funny")
# Out:
# Enter namemow
# you are nice
